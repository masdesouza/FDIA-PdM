# %% [markdown]
# <a href="https://colab.research.google.com/github/masdesouza/FDIA-PdM/blob/master/regression_CNN_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Network Fault Prediction Based on CNN-LSTM Hybrid Neural Network
# https://www.scinapse.io/papers/2969646944

# %% [markdown]
# #1. Import modules

# %%
# Regression models: How many more cycles an in-service engine will last before it fails?
import tensorflow.keras 
from tensorflow.keras.layers import Conv1D, BatchNormalization, Dropout, Dense, InputLayer, Flatten, MaxPool1D, Activation, GlobalAveragePooling1D, LSTM
from tensorflow.keras.activations import relu, softmax
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.utils import to_categorical
import tensorflow.keras.backend as K
from tensorflow.keras.models import Sequential,load_model

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn import preprocessing

# %% [markdown]
# #2. Configuration

# %%
# Setting seed for reproducibility
np.random.seed(1234)  
PYTHONHASHSEED = 0

# define path to save model
model_path = '/content/drive/MyDrive/PFC/FDIA-PdM/Trained models/CNN/regression_model_CNN.h5'

# %% [markdown]
# ##2.1  Import dataset

# %%
import os
import pickle
from google.colab import drive
from google.colab import files

drive.mount('/content/drive')
os.chdir("/content/drive/MyDrive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #3. Data Ingestion

# %%
# read training data - It is the aircraft engine run-to-failure data.
train_df = pd.read_csv('/content/drive/MyDrive/PFC/FDIA-PdM/Datasets/CMAPSSData/train_FD002.txt', sep=" ", header=None)
train_df.drop(train_df.columns[[26, 27]], axis=1, inplace=True)
train_df.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']

train_df = train_df.sort_values(['id','cycle'])

# read test data - It is the aircraft engine operating data without failure events recorded.
test_df = pd.read_csv('//content/drive/MyDrive/PFC/FDIA-PdM/Datasets/CMAPSSData/test_FD002.txt', sep=" ", header=None)
test_df.drop(test_df.columns[[26, 27]], axis=1, inplace=True)
test_df.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']

# read ground truth data - It contains the information of true remaining cycles for each engine in the testing data.
truth_df = pd.read_csv('/content/drive/MyDrive/PFC/FDIA-PdM/Datasets/CMAPSSData/RUL_FD002.txt', sep=" ", header=None)
truth_df.drop(truth_df.columns[[1]], axis=1, inplace=True)

# %% [markdown]
# #4. Data Preprocessing

# %% [markdown]
# ## 4.1 Train

# %%
# Data Labeling - generate column RUL(Remaining Usefull Life or Time to Failure)
rul = pd.DataFrame(train_df.groupby('id')['cycle'].max()).reset_index()
rul.columns = ['id', 'max']
train_df = train_df.merge(rul, on=['id'], how='left')
train_df['RUL'] = train_df['max'] - train_df['cycle']
train_df.drop('max', axis=1, inplace=True)

# generate label columns for training data
# we will only make use of "label1" for binary classification, 
# while trying to answer the question: is a specific engine going to fail within w1 cycles?
w1 = 30
w0 = 15
train_df['label1'] = np.where(train_df['RUL'] <= w1, 1, 0 )
train_df['label2'] = train_df['label1']
train_df.loc[train_df['RUL'] <= w0, 'label2'] = 2

# MinMax normalization (from 0 to 1)
train_df['cycle_norm'] = train_df['cycle']
cols_normalize = train_df.columns.difference(['id','cycle','RUL','label1','label2'])
min_max_scaler = preprocessing.MinMaxScaler()
norm_train_df = pd.DataFrame(min_max_scaler.fit_transform(train_df[cols_normalize]), 
                             columns=cols_normalize, 
                             index=train_df.index)
join_df = train_df[train_df.columns.difference(cols_normalize)].join(norm_train_df)
train_df = join_df.reindex(columns = train_df.columns)

#train_df.to_csv('../../Dataset/PredictiveTraining.csv', encoding='utf-8',index = None)

# %% [markdown]
# ## 4.2 Test

# %%
# MinMax normalization (from 0 to 1)
test_df['cycle_norm'] = test_df['cycle']
norm_test_df = pd.DataFrame(min_max_scaler.transform(test_df[cols_normalize]), 
                            columns=cols_normalize, 
                            index=test_df.index)
test_join_df = test_df[test_df.columns.difference(cols_normalize)].join(norm_test_df)
test_df = test_join_df.reindex(columns = test_df.columns)
test_df = test_df.reset_index(drop=True)
print(test_df.head())

# We use the ground truth dataset to generate labels for the test data.
# generate column max for test data
rul = pd.DataFrame(test_df.groupby('id')['cycle'].max()).reset_index()
rul.columns = ['id', 'max']
truth_df.columns = ['more']
truth_df['id'] = truth_df.index + 1
truth_df['max'] = rul['max'] + truth_df['more']
truth_df.drop('more', axis=1, inplace=True)

# generate RUL for test data
test_df = test_df.merge(truth_df, on=['id'], how='left')
test_df['RUL'] = test_df['max'] - test_df['cycle']
test_df.drop('max', axis=1, inplace=True)

# generate label columns w0 and w1 for test data
test_df['label1'] = np.where(test_df['RUL'] <= w1, 1, 0 )
test_df['label2'] = test_df['label1']
test_df.loc[test_df['RUL'] <= w0, 'label2'] = 2

#test_df.to_csv('../../Dataset/PredictiveManteinanceTest.csv', encoding='utf-8',index = None)

# pick a large window size of 50 cycles
sequence_length = 100

# function to reshape features into (samples, time steps, features) 
def gen_sequence(id_df, seq_length, seq_cols):

    data_matrix = id_df[seq_cols].values
    num_elements = data_matrix.shape[0]

    for start, stop in zip(range(0, num_elements-seq_length), range(seq_length, num_elements)):
        yield data_matrix[start:stop, :]

# pick the feature columns
sensor_cols = ['s' + str(i) for i in range(1,22)]
sequence_cols = ['setting1', 'setting2', 'setting3', 'cycle_norm']
sequence_cols.extend(sensor_cols)

# TODO for debug 
# val is a list of 192 - 50 = 142 bi-dimensional array (50 rows x 25 columns)
val=list(gen_sequence(train_df[train_df['id']==1], sequence_length, sequence_cols))
print(len(val))

# generator for the sequences
# transform each id of the train dataset in a sequence
seq_gen = (list(gen_sequence(train_df[train_df['id']==id], sequence_length, sequence_cols)) 
           for id in train_df['id'].unique())

# generate sequences and convert to numpy array
seq_array = np.concatenate(list(seq_gen)).astype(np.float32)
print(seq_array.shape)

# function to generate labels
def gen_labels(id_df, seq_length, label):

    data_matrix = id_df[label].values
    num_elements = data_matrix.shape[0]

    return data_matrix[seq_length:num_elements, :]

# generate labels
label_gen = [gen_labels(train_df[train_df['id']==id], sequence_length, ['RUL']) 
             for id in train_df['id'].unique()]

label_array = np.concatenate(label_gen).astype(np.float32)
label_array.shape
# Out:
#    id  cycle  setting1  setting2  ...  s19       s20       s21  cycle_norm
# 0   1      1  0.238019  0.297150  ...  1.0  0.625514  0.633951    0.000000
# 1   1      2  0.476162  0.831354  ...  1.0  0.483882  0.500205    0.002653
# 2   1      3  0.833282  0.997625  ...  1.0  0.164609  0.165078    0.005305
# 3   1      4  0.999967  0.998812  ...  1.0  0.005830  0.023186    0.007958
# 4   1      5  0.595089  0.737886  ...  0.0  0.141632  0.145822    0.010610
#
# [5 rows x 27 columns]
# 49
# (27759, 100, 25)
# (27759, 1)

# %% [markdown]
# # 5. Modeling

# %%
def r2_keras(y_true, y_pred):
    """Coefficient of Determination 
    """
    SS_res =  K.sum(K.square( y_true - y_pred ))
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )
def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true), axis=-1))
# Next, we build a deep network. 
# The first layer is an LSTM layer with 100 units followed by another LSTM layer with 50 units. 

nb_features = seq_array.shape[2]
nb_out = label_array.shape[1]

model = Sequential()
model.add(InputLayer(input_shape=(sequence_length, nb_features)))
model.add(BatchNormalization(axis=-1))  #Scaling the data

model.add(Conv1D(filters=64,
               kernel_size=3,
               padding="valid",
               activation="relu",
               kernel_regularizer='l2'
               )
       )


'''

model.add(Conv1D(filters=64,
               kernel_size=3,
               padding="valid",
               activation="relu",
               kernel_regularizer='l2')
       )

model.add(Conv1D(filters=64,
               kernel_size=3,
               padding="valid",
               activation="relu",
               kernel_regularizer='l2')
       )
# cnn.add(BatchNormalization(axis=-1))
# cnn.add(MaxPool1D(pool_size=2))
# cnn.add(BatchNormalization(axis=-1))

model.add(Conv1D(filters=64,
               kernel_size=3,
               padding="valid",
               activation="relu",
               kernel_regularizer='l2')
       )

model.add(Flatten())
model.add(Dense(40))
model.add(Activation('relu'))
model.add(Dense(30))
model.add(Activation('relu'))
model.add(Dense(units=nb_out))
model.add(Activation("relu"))
# cnn.add(Dense(30))

'''



model.add(LSTM(
         input_shape=(sequence_length, nb_features),
         units=100,
         return_sequences=True))


model.add(Dropout(0.2))
model.add(LSTM(
          units=100,
          return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(
          units=100,
          return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(
          units=100,
          return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=nb_out))
model.add(Activation("linear"))
model.compile(loss='mean_squared_error', optimizer='rmsprop',metrics=[rmse,r2_keras])
print(model.summary())

history = model.fit(seq_array, label_array, epochs=100, batch_size=512, validation_split=0.05, verbose=2,
          callbacks = [tensorflow.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=0, mode='min'),
                       tensorflow.keras.callbacks.ModelCheckpoint(model_path,monitor='val_loss', save_best_only=True, mode='min', verbose=0)]
    )

# model = Sequential()
# model.add(LSTM(
#          input_shape=(sequence_length, nb_features),
#          units=100,
#          return_sequences=True))
# model.add(Dropout(0.2))
# model.add(LSTM(
#           units=100,
#           return_sequences=False))
# model.add(Dropout(0.2))
# model.add(Dense(units=nb_out))
# model.add(Activation("linear"))
# model.compile(loss='mean_squared_error', optimizer='rmsprop',metrics=['mae',r2_keras])
#
# print(model.summary())
#
#
#
# # fit the network
# history = model.fit(seq_array, label_array, epochs=100, batch_size=200, validation_split=0.05, verbose=2,
#           callbacks = [keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=0, mode='min'),
#                        keras.callbacks.ModelCheckpoint(model_path,monitor='val_loss', save_best_only=True, mode='min', verbose=0)]
#           )

# list all data in history
print(history.history.keys())


# training metrics
scores = model.evaluate(seq_array, label_array, verbose=1, batch_size=200)
print('\nMAE: {}'.format(scores[1]))
print('\nR^2: {}'.format(scores[2]))

y_pred = model.predict(seq_array,verbose=1, batch_size=200)
y_true = label_array

test_set = pd.DataFrame(y_pred)
test_set.to_csv('/content/drive/MyDrive/PFC/FDIA-PdM/Output/submit_train_CNN-LSTM.csv', index = None)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_5 (Batc  (None, 100, 25)          100
#  hNormalization)
#
#  conv1d_6 (Conv1D)           (None, 98, 64)            4864
#
#  lstm_18 (LSTM)              (None, 98, 100)           66000
#
#  dropout_16 (Dropout)        (None, 98, 100)           0
#
#  lstm_19 (LSTM)              (None, 98, 100)           80400
#
#  dropout_17 (Dropout)        (None, 98, 100)           0
#
#  lstm_20 (LSTM)              (None, 98, 100)           80400
#
#  dropout_18 (Dropout)        (None, 98, 100)           0
#
#  lstm_21 (LSTM)              (None, 100)               80400
#
#  dropout_19 (Dropout)        (None, 100)               0
#
#  dense_7 (Dense)             (None, 1)                 101
#
#  activation_4 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 312,265
# Trainable params: 312,215
# Non-trainable params: 50
# _________________________________________________________________
# None
# Epoch 1/100
# 52/52 - 12s - loss: 4484.2285 - rmse: 50.2535 - r2_keras: -1.0937e+00 - val_loss: 7829.2061 - val_rmse: 66.8445 - val_r2_keras: -1.1736e+00 - 12s/epoch - 233ms/step
# Epoch 2/100
# 52/52 - 3s - loss: 3868.3381 - rmse: 45.6847 - r2_keras: -8.0204e-01 - val_loss: 7191.1729 - val_rmse: 63.5249 - val_r2_keras: -9.8902e-01 - 3s/epoch - 59ms/step
# Epoch 3/100
# 52/52 - 3s - loss: 3468.9583 - rmse: 42.8177 - r2_keras: -6.1599e-01 - val_loss: 6617.1982 - val_rmse: 60.6817 - val_r2_keras: -8.2435e-01 - 3s/epoch - 59ms/step
# Epoch 4/100
# 52/52 - 3s - loss: 3124.0754 - rmse: 40.5039 - r2_keras: -4.5601e-01 - val_loss: 6097.0049 - val_rmse: 58.2593 - val_r2_keras: -6.7654e-01 - 3s/epoch - 58ms/step
# Epoch 5/100
# 52/52 - 3s - loss: 2832.2563 - rmse: 38.6704 - r2_keras: -3.2006e-01 - val_loss: 5632.4092 - val_rmse: 56.2514 - val_r2_keras: -5.4608e-01 - 3s/epoch - 58ms/step
# Epoch 6/100
# 52/52 - 3s - loss: 2597.0491 - rmse: 37.3309 - r2_keras: -2.0952e-01 - val_loss: 5223.4307 - val_rmse: 54.6290 - val_r2_keras: -4.3295e-01 - 3s/epoch - 58ms/step
# Epoch 7/100
# 52/52 - 3s - loss: 2413.3127 - rmse: 36.4930 - r2_keras: -1.2427e-01 - val_loss: 4869.4746 - val_rmse: 53.3589 - val_r2_keras: -3.3691e-01 - 3s/epoch - 58ms/step
# Epoch 8/100
# 52/52 - 3s - loss: 2282.1121 - rmse: 36.0868 - r2_keras: -6.3231e-02 - val_loss: 4573.4194 - val_rmse: 52.4137 - val_r2_keras: -2.5859e-01 - 3s/epoch - 58ms/step
# Epoch 9/100
# 52/52 - 3s - loss: 2203.6565 - rmse: 36.0931 - r2_keras: -2.7059e-02 - val_loss: 4337.4829 - val_rmse: 51.7663 - val_r2_keras: -1.9824e-01 - 3s/epoch - 58ms/step
# Epoch 10/100
# 52/52 - 3s - loss: 2161.6340 - rmse: 36.3132 - r2_keras: -8.1391e-03 - val_loss: 4189.3516 - val_rmse: 51.4363 - val_r2_keras: -1.6185e-01 - 3s/epoch - 58ms/step
# Epoch 11/100
# 52/52 - 3s - loss: 2164.2166 - rmse: 36.5221 - r2_keras: -9.1045e-03 - val_loss: 4137.4834 - val_rmse: 51.3425 - val_r2_keras: -1.4951e-01 - 3s/epoch - 58ms/step
# Epoch 12/100
# 52/52 - 3s - loss: 2157.0486 - rmse: 36.5574 - r2_keras: -5.8887e-03 - val_loss: 4190.1489 - val_rmse: 51.4371 - val_r2_keras: -1.6203e-01 - 3s/epoch - 57ms/step
# Epoch 13/100
# 52/52 - 3s - loss: 2160.1206 - rmse: 36.3615 - r2_keras: -6.3951e-03 - val_loss: 4024.4946 - val_rmse: 50.7759 - val_r2_keras: -1.0829e-01 - 3s/epoch - 58ms/step
# Epoch 14/100
# 52/52 - 3s - loss: 1782.4697 - rmse: 31.4741 - r2_keras: 0.1702 - val_loss: 3450.3184 - val_rmse: 45.2687 - val_r2_keras: 0.0743 - 3s/epoch - 58ms/step
# Epoch 15/100
# 52/52 - 3s - loss: 1450.0870 - rmse: 27.0622 - r2_keras: 0.3241 - val_loss: 2794.0835 - val_rmse: 36.6547 - val_r2_keras: 0.2574 - 3s/epoch - 58ms/step
# Epoch 16/100
# 52/52 - 3s - loss: 1274.5905 - rmse: 24.6734 - r2_keras: 0.4079 - val_loss: 2756.0793 - val_rmse: 36.5194 - val_r2_keras: 0.2792 - 3s/epoch - 59ms/step
# Epoch 17/100
# 52/52 - 3s - loss: 1210.9987 - rmse: 23.5979 - r2_keras: 0.4348 - val_loss: 2499.6294 - val_rmse: 36.6342 - val_r2_keras: 0.3225 - 3s/epoch - 58ms/step
# Epoch 18/100
# 52/52 - 3s - loss: 1094.7544 - rmse: 22.6788 - r2_keras: 0.4909 - val_loss: 2186.0525 - val_rmse: 32.4171 - val_r2_keras: 0.4268 - 3s/epoch - 58ms/step
# Epoch 19/100
# 52/52 - 3s - loss: 1025.7479 - rmse: 21.8689 - r2_keras: 0.5239 - val_loss: 1998.3723 - val_rmse: 30.5797 - val_r2_keras: 0.4703 - 3s/epoch - 59ms/step
# Epoch 20/100
# 52/52 - 3s - loss: 942.1456 - rmse: 20.8295 - r2_keras: 0.5608 - val_loss: 1779.2762 - val_rmse: 27.9872 - val_r2_keras: 0.5399 - 3s/epoch - 58ms/step
# Epoch 21/100
# 52/52 - 3s - loss: 890.9025 - rmse: 20.1996 - r2_keras: 0.5860 - val_loss: 1747.7894 - val_rmse: 27.1834 - val_r2_keras: 0.5466 - 3s/epoch - 59ms/step
# Epoch 22/100
# 52/52 - 3s - loss: 835.6901 - rmse: 19.4930 - r2_keras: 0.6110 - val_loss: 1643.0560 - val_rmse: 26.2293 - val_r2_keras: 0.5822 - 3s/epoch - 58ms/step
# Epoch 23/100
# 52/52 - 3s - loss: 798.7328 - rmse: 19.0176 - r2_keras: 0.6281 - val_loss: 1644.5181 - val_rmse: 27.3089 - val_r2_keras: 0.5660 - 3s/epoch - 57ms/step
# Epoch 24/100
# 52/52 - 3s - loss: 753.4445 - rmse: 18.5319 - r2_keras: 0.6492 - val_loss: 1513.7986 - val_rmse: 25.2501 - val_r2_keras: 0.6001 - 3s/epoch - 58ms/step
# Epoch 25/100
# 52/52 - 3s - loss: 724.7731 - rmse: 18.1536 - r2_keras: 0.6617 - val_loss: 1319.2611 - val_rmse: 25.1308 - val_r2_keras: 0.6498 - 3s/epoch - 58ms/step
# Epoch 26/100
# 52/52 - 3s - loss: 683.6692 - rmse: 17.5628 - r2_keras: 0.6819 - val_loss: 1356.3757 - val_rmse: 22.8043 - val_r2_keras: 0.6577 - 3s/epoch - 57ms/step
# Epoch 27/100
# 52/52 - 3s - loss: 744.4753 - rmse: 18.5235 - r2_keras: 0.6541 - val_loss: 1092.1173 - val_rmse: 20.9147 - val_r2_keras: 0.7210 - 3s/epoch - 58ms/step
# Epoch 28/100
# 52/52 - 3s - loss: 645.6160 - rmse: 17.0690 - r2_keras: 0.6983 - val_loss: 1339.8508 - val_rmse: 26.9249 - val_r2_keras: 0.6319 - 3s/epoch - 57ms/step
# Epoch 29/100
# 52/52 - 3s - loss: 614.8268 - rmse: 16.6098 - r2_keras: 0.7135 - val_loss: 1058.5986 - val_rmse: 21.7688 - val_r2_keras: 0.7214 - 3s/epoch - 58ms/step
# Epoch 30/100
# 52/52 - 3s - loss: 600.1946 - rmse: 16.5203 - r2_keras: 0.7200 - val_loss: 1097.1241 - val_rmse: 22.9199 - val_r2_keras: 0.6992 - 3s/epoch - 57ms/step
# Epoch 31/100
# 52/52 - 3s - loss: 562.6245 - rmse: 15.8405 - r2_keras: 0.7378 - val_loss: 1170.8230 - val_rmse: 21.7931 - val_r2_keras: 0.7123 - 3s/epoch - 57ms/step
# Epoch 32/100
# 52/52 - 3s - loss: 550.4713 - rmse: 15.7047 - r2_keras: 0.7423 - val_loss: 1045.2145 - val_rmse: 19.6448 - val_r2_keras: 0.7471 - 3s/epoch - 63ms/step
# Epoch 33/100
# 52/52 - 3s - loss: 569.9824 - rmse: 15.8002 - r2_keras: 0.7354 - val_loss: 896.3635 - val_rmse: 19.8409 - val_r2_keras: 0.7553 - 3s/epoch - 58ms/step
# Epoch 34/100
# 52/52 - 3s - loss: 505.9747 - rmse: 14.9635 - r2_keras: 0.7640 - val_loss: 996.3729 - val_rmse: 19.5796 - val_r2_keras: 0.7397 - 3s/epoch - 57ms/step
# Epoch 35/100
# 52/52 - 3s - loss: 494.3471 - rmse: 14.7211 - r2_keras: 0.7703 - val_loss: 892.0646 - val_rmse: 19.0687 - val_r2_keras: 0.7668 - 3s/epoch - 59ms/step
# Epoch 36/100
# 52/52 - 3s - loss: 474.3739 - rmse: 14.4572 - r2_keras: 0.7783 - val_loss: 932.2284 - val_rmse: 18.3848 - val_r2_keras: 0.7656 - 3s/epoch - 57ms/step
# Epoch 37/100
# 52/52 - 3s - loss: 457.3445 - rmse: 14.1743 - r2_keras: 0.7873 - val_loss: 1056.5554 - val_rmse: 20.1349 - val_r2_keras: 0.7382 - 3s/epoch - 57ms/step
# Epoch 38/100
# 52/52 - 3s - loss: 427.5086 - rmse: 13.6089 - r2_keras: 0.8014 - val_loss: 896.4498 - val_rmse: 20.0754 - val_r2_keras: 0.7752 - 3s/epoch - 57ms/step
# Epoch 39/100
# 52/52 - 3s - loss: 422.8743 - rmse: 13.6139 - r2_keras: 0.8034 - val_loss: 1047.5092 - val_rmse: 25.3384 - val_r2_keras: 0.7031 - 3s/epoch - 57ms/step
# Epoch 40/100
# 52/52 - 3s - loss: 440.4608 - rmse: 13.6905 - r2_keras: 0.7945 - val_loss: 879.8091 - val_rmse: 17.6065 - val_r2_keras: 0.7891 - 3s/epoch - 63ms/step
# Epoch 41/100
# 52/52 - 3s - loss: 378.4257 - rmse: 12.8580 - r2_keras: 0.8238 - val_loss: 1337.1334 - val_rmse: 25.3286 - val_r2_keras: 0.6658 - 3s/epoch - 57ms/step
# Epoch 42/100
# 52/52 - 3s - loss: 392.2698 - rmse: 13.0137 - r2_keras: 0.8167 - val_loss: 786.0216 - val_rmse: 17.9176 - val_r2_keras: 0.8046 - 3s/epoch - 58ms/step
# Epoch 43/100
# 52/52 - 3s - loss: 344.3885 - rmse: 12.2109 - r2_keras: 0.8389 - val_loss: 777.2874 - val_rmse: 18.2132 - val_r2_keras: 0.7992 - 3s/epoch - 59ms/step
# Epoch 44/100
# 52/52 - 3s - loss: 328.6426 - rmse: 11.9479 - r2_keras: 0.8467 - val_loss: 805.1107 - val_rmse: 16.9655 - val_r2_keras: 0.7913 - 3s/epoch - 57ms/step
# Epoch 45/100
# 52/52 - 3s - loss: 322.5670 - rmse: 11.8224 - r2_keras: 0.8501 - val_loss: 935.3361 - val_rmse: 17.3383 - val_r2_keras: 0.7738 - 3s/epoch - 57ms/step
# Epoch 46/100
# 52/52 - 3s - loss: 309.0254 - rmse: 11.5056 - r2_keras: 0.8562 - val_loss: 824.2743 - val_rmse: 17.2669 - val_r2_keras: 0.7961 - 3s/epoch - 57ms/step
# Epoch 47/100
# 52/52 - 3s - loss: 282.4967 - rmse: 11.0214 - r2_keras: 0.8685 - val_loss: 1603.6989 - val_rmse: 26.0400 - val_r2_keras: 0.5891 - 3s/epoch - 57ms/step
# Epoch 48/100
# 52/52 - 3s - loss: 270.1371 - rmse: 10.8254 - r2_keras: 0.8746 - val_loss: 882.6239 - val_rmse: 17.7490 - val_r2_keras: 0.7740 - 3s/epoch - 57ms/step
# Epoch 49/100
# 52/52 - 3s - loss: 276.6377 - rmse: 10.9331 - r2_keras: 0.8718 - val_loss: 946.3054 - val_rmse: 17.9922 - val_r2_keras: 0.7613 - 3s/epoch - 57ms/step
# Epoch 50/100
# 52/52 - 3s - loss: 240.5549 - rmse: 10.2466 - r2_keras: 0.8877 - val_loss: 1934.1382 - val_rmse: 27.2183 - val_r2_keras: 0.4954 - 3s/epoch - 57ms/step
# Epoch 51/100
# 52/52 - 3s - loss: 244.3199 - rmse: 10.2321 - r2_keras: 0.8872 - val_loss: 898.1072 - val_rmse: 18.3068 - val_r2_keras: 0.7752 - 3s/epoch - 57ms/step
# Epoch 52/100
# 52/52 - 3s - loss: 219.7605 - rmse: 9.7731 - r2_keras: 0.8976 - val_loss: 725.6077 - val_rmse: 18.3127 - val_r2_keras: 0.8072 - 3s/epoch - 64ms/step
# Epoch 53/100
# 52/52 - 3s - loss: 217.6043 - rmse: 9.7213 - r2_keras: 0.8992 - val_loss: 792.4406 - val_rmse: 17.3275 - val_r2_keras: 0.7948 - 3s/epoch - 57ms/step
# Epoch 54/100
# 52/52 - 3s - loss: 192.0097 - rmse: 9.1523 - r2_keras: 0.9109 - val_loss: 971.0107 - val_rmse: 19.0041 - val_r2_keras: 0.7526 - 3s/epoch - 57ms/step
# Epoch 55/100
# 52/52 - 3s - loss: 178.1531 - rmse: 8.8575 - r2_keras: 0.9172 - val_loss: 722.3189 - val_rmse: 16.4198 - val_r2_keras: 0.8190 - 3s/epoch - 63ms/step
# Epoch 56/100
# 52/52 - 3s - loss: 177.9029 - rmse: 8.7799 - r2_keras: 0.9168 - val_loss: 1403.6980 - val_rmse: 22.9454 - val_r2_keras: 0.6271 - 3s/epoch - 57ms/step
# Epoch 57/100
# 52/52 - 3s - loss: 168.2817 - rmse: 8.4918 - r2_keras: 0.9217 - val_loss: 762.0187 - val_rmse: 15.6506 - val_r2_keras: 0.8165 - 3s/epoch - 57ms/step
# Epoch 58/100
# 52/52 - 3s - loss: 164.5215 - rmse: 8.4357 - r2_keras: 0.9233 - val_loss: 923.7006 - val_rmse: 17.1159 - val_r2_keras: 0.7744 - 3s/epoch - 57ms/step
# Epoch 59/100
# 52/52 - 3s - loss: 150.0313 - rmse: 7.8763 - r2_keras: 0.9301 - val_loss: 980.6339 - val_rmse: 17.2608 - val_r2_keras: 0.7594 - 3s/epoch - 57ms/step
# Epoch 60/100
# 52/52 - 3s - loss: 139.2529 - rmse: 7.8636 - r2_keras: 0.9347 - val_loss: 995.4057 - val_rmse: 17.6291 - val_r2_keras: 0.7641 - 3s/epoch - 57ms/step
# Epoch 61/100
# 52/52 - 3s - loss: 132.8221 - rmse: 7.6224 - r2_keras: 0.9381 - val_loss: 1015.0701 - val_rmse: 17.3171 - val_r2_keras: 0.7492 - 3s/epoch - 57ms/step
# Epoch 62/100
# 52/52 - 3s - loss: 134.6716 - rmse: 7.6666 - r2_keras: 0.9371 - val_loss: 1008.7073 - val_rmse: 22.1176 - val_r2_keras: 0.7471 - 3s/epoch - 57ms/step
# Epoch 63/100
# 52/52 - 3s - loss: 121.4100 - rmse: 7.2415 - r2_keras: 0.9433 - val_loss: 1212.1365 - val_rmse: 22.0486 - val_r2_keras: 0.6961 - 3s/epoch - 57ms/step
# Epoch 64/100
# 52/52 - 3s - loss: 120.2266 - rmse: 7.2352 - r2_keras: 0.9443 - val_loss: 973.1813 - val_rmse: 17.9107 - val_r2_keras: 0.7571 - 3s/epoch - 57ms/step
# Epoch 65/100
# 52/52 - 3s - loss: 104.1069 - rmse: 6.8204 - r2_keras: 0.9514 - val_loss: 1055.5115 - val_rmse: 18.9201 - val_r2_keras: 0.7443 - 3s/epoch - 57ms/step
# dict_keys(['loss', 'rmse', 'r2_keras', 'val_loss', 'val_rmse', 'val_r2_keras'])
# 139/139 [==============================] - 2s 17ms/step - loss: 123.9557 - rmse: 6.4083 - r2_keras: 0.9436
#
# MAE: 6.408253192901611
#
# R^2: 0.9435741901397705
# 139/139 [==============================] - 4s 14ms/step

# %% [markdown]
# #6. EVALUATE ON TEST DATA

# %%
# We pick the last sequence for each id in the test data
seq_array_test_last = [test_df[test_df['id']==id][sequence_cols].values[-sequence_length:] 
                       for id in test_df['id'].unique() if len(test_df[test_df['id']==id]) >= sequence_length]

seq_array_test_last = np.asarray(seq_array_test_last).astype(np.float32)
print("seq_array_test_last")
#print(seq_array_test_last)
print(seq_array_test_last.shape)

# Similarly, we pick the labels
#print("y_mask")
y_mask = [len(test_df[test_df['id']==id]) >= sequence_length for id in test_df['id'].unique()]
label_array_test_last = test_df.groupby('id')['RUL'].nth(-1)[y_mask].values
label_array_test_last = label_array_test_last.reshape(label_array_test_last.shape[0],1).astype(np.float32)
print(label_array_test_last.shape)
print("label_array_test_last")
print(label_array_test_last)

# if best iteration's model was saved then load and use it
if os.path.isfile(model_path):
    model.load_weights(model_path)
    #estimator = load_model(model_path,custom_objects={'r2_keras': r2_keras})

    # test metrics
    scores_test = model.evaluate(seq_array_test_last, label_array_test_last, verbose=2)
    print('\nMAE: {}'.format(scores_test[1]))
    print('\nR^2: {}'.format(scores_test[2]))

    y_pred_test = model.predict(seq_array_test_last)
    y_true_test = label_array_test_last
    print("Prediction")
    print(y_pred_test);
    print("Truth")
    print(y_true_test);

    # Plot in blue color the predicted data and in green color the
    # actual data to verify visually the accuracy of the model.
    fig_verify = plt.figure(figsize=(100, 50))
    plt.plot(y_pred_test, color="blue")
    plt.plot(y_true_test, color="green")
    plt.title('prediction')
    plt.ylabel('RUL in cycles')
    plt.xlabel('Engine ID')
    plt.legend(['predicted', 'actual data'], loc='upper left')
    plt.show()
    fig_verify.savefig("/content/drive/MyDrive/PFC/FDIA-PdM/Output/model_regression_verify_CNN.png")
# Out:
# seq_array_test_last
# (168, 100, 25)
# (168, 1)
# label_array_test_last
# [[ 18.]
#  [106.]
#  [ 15.]
#  [  6.]
#  [ 90.]
#  [ 11.]
#  [  6.]
#  [ 30.]
#  [ 11.]
#  [ 37.]
#  [ 68.]
#  [ 22.]
#  [ 54.]
#  [ 97.]
#  [ 10.]
#  [ 77.]
#  [ 88.]
#  [ 83.]
#  [ 78.]
#  [ 75.]
#  [ 11.]
#  [ 53.]
#  [100.]
#  [ 55.]
#  [ 48.]
#  [ 37.]
#  [ 44.]
#  [ 27.]
#  [ 18.]
#  [  6.]
#  [ 15.]
#  [112.]
#  [ 13.]
#  [ 13.]
#  [ 53.]
#  [ 52.]
#  [103.]
#  [ 26.]
#  [ 73.]
#  [ 39.]
#  [ 39.]
#  [ 14.]
#  [ 11.]
#  [ 86.]
#  [ 56.]
#  [115.]
#  [ 17.]
#  [104.]
#  [ 78.]
#  [ 86.]
#  [ 98.]
#  [ 36.]
#  [ 52.]
#  [ 91.]
#  [ 15.]
#  [ 17.]
#  [ 47.]
#  [ 21.]
#  [ 79.]
#  [  8.]
#  [  9.]
#  [ 73.]
#  [ 97.]
#  [ 49.]
#  [ 31.]
#  [ 97.]
#  [  9.]
#  [ 14.]
#  [  8.]
#  [  8.]
#  [106.]
#  [ 61.]
#  [168.]
#  [ 35.]
#  [ 80.]
#  [  9.]
#  [ 50.]
#  [ 78.]
#  [ 91.]
#  [  7.]
#  [106.]
#  [ 15.]
#  [  7.]
#  [ 82.]
#  [108.]
#  [ 79.]
#  [121.]
#  [ 39.]
#  [ 38.]
#  [  9.]
#  [167.]
#  [ 88.]
#  [  7.]
#  [ 51.]
#  [ 55.]
#  [ 47.]
#  [ 81.]
#  [ 43.]
#  [ 98.]
#  [ 10.]
#  [ 11.]
#  [ 34.]
#  [115.]
#  [ 99.]
#  [171.]
#  [ 15.]
#  [  9.]
#  [ 42.]
#  [ 13.]
#  [ 41.]
#  [ 88.]
#  [ 14.]
#  [ 82.]
#  [ 36.]
#  [107.]
#  [ 14.]
#  [ 23.]
#  [  6.]
#  [ 35.]
#  [ 97.]
#  [ 68.]
#  [ 14.]
#  [ 67.]
#  [ 19.]
#  [ 10.]
#  [ 43.]
#  [ 12.]
#  [ 13.]
#  [ 37.]
#  [ 80.]
#  [ 93.]
#  [ 32.]
#  [103.]
#  [ 68.]
#  [192.]
#  [ 48.]
#  [ 85.]
#  [  8.]
#  [ 23.]
#  [  8.]
#  [  6.]
#  [ 57.]
#  [ 83.]
#  [ 81.]
#  [ 73.]
#  [ 75.]
#  [ 11.]
#  [108.]
#  [ 14.]
#  [ 61.]
#  [ 85.]
#  [  8.]
#  [101.]
#  [ 89.]
#  [190.]
#  [ 12.]
#  [ 62.]
#  [101.]
#  [ 17.]
#  [ 16.]
#  [ 56.]
#  [ 23.]
#  [ 12.]
#  [ 43.]
#  [ 48.]
#  [122.]
#  [ 56.]
#  [ 51.]]
# 6/6 - 0s - loss: 286.2981 - rmse: 10.8971 - r2_keras: 0.8085 - 102ms/epoch - 17ms/step
#
# MAE: 10.897050857543945
#
# R^2: 0.8085370659828186
# Prediction
# [[ 12.565487 ]
#  [ 87.89564  ]
#  [ 20.244398 ]
#  [  7.87084  ]
#  [ 79.64905  ]
#  [ 11.065087 ]
#  [  7.8188405]
#  [ 33.43957  ]
#  [ 11.918095 ]
#  [ 44.056015 ]
#  [ 94.95113  ]
#  [ 29.23359  ]
#  [ 69.122025 ]
#  [ 83.36247  ]
#  [ 16.103512 ]
#  [117.798485 ]
#  [113.51872  ]
#  [ 96.14471  ]
#  [ 79.11989  ]
#  [ 69.31593  ]
#  [ 15.1348915]
#  [ 67.18366  ]
#  [116.57944  ]
#  [ 61.489082 ]
#  [ 44.054436 ]
#  [ 39.36755  ]
#  [ 44.717613 ]
#  [ 30.341751 ]
#  [ 26.493826 ]
#  [ 12.640862 ]
#  [ 18.907082 ]
#  [121.08216  ]
#  [ 15.881232 ]
#  [ 15.555705 ]
#  [ 45.34308  ]
#  [ 48.42615  ]
#  [ 96.93503  ]
#  [ 28.954159 ]
#  [ 62.788315 ]
#  [ 30.469503 ]
#  [ 57.510967 ]
#  [ 21.108553 ]
#  [ 22.604515 ]
#  [100.49548  ]
#  [ 55.931908 ]
#  [134.63974  ]
#  [ 18.836926 ]
#  [114.84323  ]
#  [ 84.69451  ]
#  [ 85.868126 ]
#  [140.84802  ]
#  [ 36.241074 ]
#  [ 61.107037 ]
#  [124.724594 ]
#  [ 19.404243 ]
#  [ 18.193169 ]
#  [ 46.831345 ]
#  [ 35.88841  ]
#  [ 90.87649  ]
#  [ 10.0781555]
#  [ 16.33016  ]
#  [121.038155 ]
#  [121.9164   ]
#  [ 50.929523 ]
#  [ 28.174082 ]
#  [ 78.339165 ]
#  [  7.464813 ]
#  [ 18.817848 ]
#  [  7.2965784]
#  [ 12.364174 ]
#  [ 83.94731  ]
#  [ 73.70071  ]
#  [ 75.00649  ]
#  [ 32.599762 ]
#  [100.20084  ]
#  [ 16.317457 ]
#  [ 65.16639  ]
#  [ 78.17708  ]
#  [ 86.04747  ]
#  [  7.5827756]
#  [ 70.95934  ]
#  [ 23.875763 ]
#  [ 14.426716 ]
#  [ 70.12055  ]
#  [ 81.54505  ]
#  [ 68.18198  ]
#  [114.48614  ]
#  [ 56.162758 ]
#  [ 62.72054  ]
#  [  5.816741 ]
#  [144.14029  ]
#  [ 96.5587   ]
#  [  9.587387 ]
#  [ 57.827606 ]
#  [ 60.048817 ]
#  [ 65.52067  ]
#  [103.0424   ]
#  [ 65.59372  ]
#  [ 84.40826  ]
#  [ 12.142378 ]
#  [ 10.192607 ]
#  [ 36.160896 ]
#  [100.00044  ]
#  [105.61093  ]
#  [101.89233  ]
#  [ 28.179821 ]
#  [  9.602259 ]
#  [ 51.668922 ]
#  [ 19.459484 ]
#  [ 49.542072 ]
#  [ 75.06026  ]
#  [ 11.685456 ]
#  [ 81.472595 ]
#  [ 39.649597 ]
#  [107.12609  ]
#  [ 13.988939 ]
#  [ 26.49197  ]
#  [  7.850662 ]
#  [ 59.18913  ]
#  [ 98.00002  ]
#  [ 61.071648 ]
#  [ 18.878784 ]
#  [ 73.3586   ]
#  [ 18.889786 ]
#  [ 11.217239 ]
#  [ 52.116615 ]
#  [ 20.726665 ]
#  [ 21.641768 ]
#  [ 36.106647 ]
#  [ 61.14058  ]
#  [154.02135  ]
#  [ 41.81743  ]
#  [113.99532  ]
#  [ 80.24315  ]
#  [167.92929  ]
#  [ 59.09896  ]
#  [ 74.77944  ]
#  [  5.370805 ]
#  [ 32.036903 ]
#  [ 10.046178 ]
#  [ 10.1587105]
#  [ 50.63032  ]
#  [ 92.588066 ]
#  [ 98.14552  ]
#  [ 63.051956 ]
#  [ 74.75784  ]
#  [ 18.855804 ]
#  [124.02652  ]
#  [  5.0675583]
#  [ 97.55986  ]
#  [115.872894 ]
#  [  4.245916 ]
#  [ 99.42985  ]
#  [ 64.034035 ]
#  [163.57733  ]
#  [ 20.011444 ]
#  [ 48.439747 ]
#  [118.02101  ]
#  [ 20.332024 ]
#  [ 13.657476 ]
#  [ 58.403816 ]
#  [ 23.558174 ]
#  [ 14.24604  ]
#  [ 43.07232  ]
#  [ 45.39094  ]
#  [ 79.29375  ]
#  [ 54.613853 ]
#  [ 63.985447 ]]
# Truth
# [[ 18.]
#  [106.]
#  [ 15.]
#  [  6.]
#  [ 90.]
#  [ 11.]
#  [  6.]
#  [ 30.]
#  [ 11.]
#  [ 37.]
#  [ 68.]
#  [ 22.]
#  [ 54.]
#  [ 97.]
#  [ 10.]
#  [ 77.]
#  [ 88.]
#  [ 83.]
#  [ 78.]
#  [ 75.]
#  [ 11.]
#  [ 53.]
#  [100.]
#  [ 55.]
#  [ 48.]
#  [ 37.]
#  [ 44.]
#  [ 27.]
#  [ 18.]
#  [  6.]
#  [ 15.]
#  [112.]
#  [ 13.]
#  [ 13.]
#  [ 53.]
#  [ 52.]
#  [103.]
#  [ 26.]
#  [ 73.]
#  [ 39.]
#  [ 39.]
#  [ 14.]
#  [ 11.]
#  [ 86.]
#  [ 56.]
#  [115.]
#  [ 17.]
#  [104.]
#  [ 78.]
#  [ 86.]
#  [ 98.]
#  [ 36.]
#  [ 52.]
#  [ 91.]
#  [ 15.]
#  [ 17.]
#  [ 47.]
#  [ 21.]
#  [ 79.]
#  [  8.]
#  [  9.]
#  [ 73.]
#  [ 97.]
#  [ 49.]
#  [ 31.]
#  [ 97.]
#  [  9.]
#  [ 14.]
#  [  8.]
#  [  8.]
#  [106.]
#  [ 61.]
#  [168.]
#  [ 35.]
#  [ 80.]
#  [  9.]
#  [ 50.]
#  [ 78.]
#  [ 91.]
#  [  7.]
#  [106.]
#  [ 15.]
#  [  7.]
#  [ 82.]
#  [108.]
#  [ 79.]
#  [121.]
#  [ 39.]
#  [ 38.]
#  [  9.]
#  [167.]
#  [ 88.]
#  [  7.]
#  [ 51.]
#  [ 55.]
#  [ 47.]
#  [ 81.]
#  [ 43.]
#  [ 98.]
#  [ 10.]
#  [ 11.]
#  [ 34.]
#  [115.]
#  [ 99.]
#  [171.]
#  [ 15.]
#  [  9.]
#  [ 42.]
#  [ 13.]
#  [ 41.]
#  [ 88.]
#  [ 14.]
#  [ 82.]
#  [ 36.]
#  [107.]
#  [ 14.]
#  [ 23.]
#  [  6.]
#  [ 35.]
#  [ 97.]
#  [ 68.]
#  [ 14.]
#  [ 67.]
#  [ 19.]
#  [ 10.]
#  [ 43.]
#  [ 12.]
#  [ 13.]
#  [ 37.]
#  [ 80.]
#  [ 93.]
#  [ 32.]
#  [103.]
#  [ 68.]
#  [192.]
#  [ 48.]
#  [ 85.]
#  [  8.]
#  [ 23.]
#  [  8.]
#  [  6.]
#  [ 57.]
#  [ 83.]
#  [ 81.]
#  [ 73.]
#  [ 75.]
#  [ 11.]
#  [108.]
#  [ 14.]
#  [ 61.]
#  [ 85.]
#  [  8.]
#  [101.]
#  [ 89.]
#  [190.]
#  [ 12.]
#  [ 62.]
#  [101.]
#  [ 17.]
#  [ 16.]
#  [ 56.]
#  [ 23.]
#  [ 12.]
#  [ 43.]
#  [ 48.]
#  [122.]
#  [ 56.]
#  [ 51.]]
