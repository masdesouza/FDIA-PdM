# %% [markdown]
# <a href="https://colab.research.google.com/github/masdesouza/FDIA-PdM/blob/master/regression_CNN_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Network Fault Prediction Based on CNN-LSTM Hybrid Neural Network
# https://www.scinapse.io/papers/2969646944

# %% [markdown]
# #1. Import modules

# %%
# Regression models: How many more cycles an in-service engine will last before it fails?
import tensorflow.keras 
from tensorflow.keras.layers import Conv1D, BatchNormalization, Dropout, Dense, InputLayer, Flatten, MaxPool1D, Activation, GlobalAveragePooling1D, LSTM
from tensorflow.keras.activations import relu, softmax
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.utils import to_categorical
import tensorflow.keras.backend as K
from tensorflow.keras.models import Sequential,load_model

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn import preprocessing

# %% [markdown]
# #2. Configuration

# %%
# Setting seed for reproducibility
np.random.seed(1234)  
PYTHONHASHSEED = 0

# define path to save model
model_path = '/content/drive/MyDrive/PFC/FDIA-PdM/Trained models/CNN/regression_model_CNN-LSTM.h5'

# %% [markdown]
# ##2.1  Import dataset

# %%
import os
import pickle
from google.colab import drive
from google.colab import files

drive.mount('/content/drive')
os.chdir("/content/drive/MyDrive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# #3. Data Ingestion

# %%
# read training data - It is the aircraft engine run-to-failure data.
train_df = pd.read_csv('/content/drive/MyDrive/PFC/FDIA-PdM/Datasets/CMAPSSData/train_FD002.txt', sep=" ", header=None)
train_df.drop(train_df.columns[[26, 27]], axis=1, inplace=True)
train_df.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']

train_df = train_df.sort_values(['id','cycle'])

# read test data - It is the aircraft engine operating data without failure events recorded.
test_df = pd.read_csv('//content/drive/MyDrive/PFC/FDIA-PdM/Datasets/CMAPSSData/test_FD002.txt', sep=" ", header=None)
test_df.drop(test_df.columns[[26, 27]], axis=1, inplace=True)
test_df.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']

# read ground truth data - It contains the information of true remaining cycles for each engine in the testing data.
truth_df = pd.read_csv('/content/drive/MyDrive/PFC/FDIA-PdM/Datasets/CMAPSSData/RUL_FD002.txt', sep=" ", header=None)
truth_df.drop(truth_df.columns[[1]], axis=1, inplace=True)

# %% [markdown]
# #4. Data Preprocessing

# %% [markdown]
# ## 4.1 Train

# %%
# Data Labeling - generate column RUL(Remaining Usefull Life or Time to Failure)
rul = pd.DataFrame(train_df.groupby('id')['cycle'].max()).reset_index()
rul.columns = ['id', 'max']
train_df = train_df.merge(rul, on=['id'], how='left')
train_df['RUL'] = train_df['max'] - train_df['cycle']
train_df.drop('max', axis=1, inplace=True)

# generate label columns for training data
# we will only make use of "label1" for binary classification, 
# while trying to answer the question: is a specific engine going to fail within w1 cycles?
w1 = 30
w0 = 15
train_df['label1'] = np.where(train_df['RUL'] <= w1, 1, 0 )
train_df['label2'] = train_df['label1']
train_df.loc[train_df['RUL'] <= w0, 'label2'] = 2

# MinMax normalization (from 0 to 1)
train_df['cycle_norm'] = train_df['cycle']
cols_normalize = train_df.columns.difference(['id','cycle','RUL','label1','label2'])
min_max_scaler = preprocessing.MinMaxScaler()
norm_train_df = pd.DataFrame(min_max_scaler.fit_transform(train_df[cols_normalize]), 
                             columns=cols_normalize, 
                             index=train_df.index)
join_df = train_df[train_df.columns.difference(cols_normalize)].join(norm_train_df)
train_df = join_df.reindex(columns = train_df.columns)

#train_df.to_csv('../../Dataset/PredictiveTraining.csv', encoding='utf-8',index = None)

# %% [markdown]
# ## 4.2 Test

# %%
# MinMax normalization (from 0 to 1)
test_df['cycle_norm'] = test_df['cycle']
norm_test_df = pd.DataFrame(min_max_scaler.transform(test_df[cols_normalize]), 
                            columns=cols_normalize, 
                            index=test_df.index)
test_join_df = test_df[test_df.columns.difference(cols_normalize)].join(norm_test_df)
test_df = test_join_df.reindex(columns = test_df.columns)
test_df = test_df.reset_index(drop=True)
print(test_df.head())

# We use the ground truth dataset to generate labels for the test data.
# generate column max for test data
rul = pd.DataFrame(test_df.groupby('id')['cycle'].max()).reset_index()
rul.columns = ['id', 'max']
truth_df.columns = ['more']
truth_df['id'] = truth_df.index + 1
truth_df['max'] = rul['max'] + truth_df['more']
truth_df.drop('more', axis=1, inplace=True)

# generate RUL for test data
test_df = test_df.merge(truth_df, on=['id'], how='left')
test_df['RUL'] = test_df['max'] - test_df['cycle']
test_df.drop('max', axis=1, inplace=True)

# generate label columns w0 and w1 for test data
test_df['label1'] = np.where(test_df['RUL'] <= w1, 1, 0 )
test_df['label2'] = test_df['label1']
test_df.loc[test_df['RUL'] <= w0, 'label2'] = 2

#test_df.to_csv('../../Dataset/PredictiveManteinanceTest.csv', encoding='utf-8',index = None)

# pick a large window size of 50 cycles
sequence_length = 100

# function to reshape features into (samples, time steps, features) 
def gen_sequence(id_df, seq_length, seq_cols):

    data_matrix = id_df[seq_cols].values
    num_elements = data_matrix.shape[0]

    for start, stop in zip(range(0, num_elements-seq_length), range(seq_length, num_elements)):
        yield data_matrix[start:stop, :]

# pick the feature columns
sensor_cols = ['s' + str(i) for i in range(1,22)]
sequence_cols = ['setting1', 'setting2', 'setting3', 'cycle_norm']
sequence_cols.extend(sensor_cols)

# TODO for debug 
# val is a list of 192 - 50 = 142 bi-dimensional array (50 rows x 25 columns)
val=list(gen_sequence(train_df[train_df['id']==1], sequence_length, sequence_cols))
print(len(val))

# generator for the sequences
# transform each id of the train dataset in a sequence
seq_gen = (list(gen_sequence(train_df[train_df['id']==id], sequence_length, sequence_cols)) 
           for id in train_df['id'].unique())

# generate sequences and convert to numpy array
seq_array = np.concatenate(list(seq_gen)).astype(np.float32)
print(seq_array.shape)

# function to generate labels
def gen_labels(id_df, seq_length, label):

    data_matrix = id_df[label].values
    num_elements = data_matrix.shape[0]

    return data_matrix[seq_length:num_elements, :]

# generate labels
label_gen = [gen_labels(train_df[train_df['id']==id], sequence_length, ['RUL']) 
             for id in train_df['id'].unique()]

label_array = np.concatenate(label_gen).astype(np.float32)
label_array.shape
# Out:
#    id  cycle  setting1  setting2  ...  s19       s20       s21  cycle_norm
# 0   1      1  0.238019  0.297150  ...  1.0  0.625514  0.633951    0.000000
# 1   1      2  0.476162  0.831354  ...  1.0  0.483882  0.500205    0.002653
# 2   1      3  0.833282  0.997625  ...  1.0  0.164609  0.165078    0.005305
# 3   1      4  0.999967  0.998812  ...  1.0  0.005830  0.023186    0.007958
# 4   1      5  0.595089  0.737886  ...  0.0  0.141632  0.145822    0.010610
#
# [5 rows x 27 columns]
# 49
# (27759, 100, 25)
# (27759, 1)

# %% [markdown]
# # 5. Modeling

# %%
def r2_keras(y_true, y_pred):
    """Coefficient of Determination 
    """
    SS_res =  K.sum(K.square( y_true - y_pred ))
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )
def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true), axis=-1))
# Next, we build a deep network. 
# The first layer is an LSTM layer with 100 units followed by another LSTM layer with 50 units. 

nb_features = seq_array.shape[2]
nb_out = label_array.shape[1]

model = Sequential()
model.add(InputLayer(input_shape=(sequence_length, nb_features)))
model.add(BatchNormalization(axis=-1))  #Scaling the data

model.add(Conv1D(filters=64,
               kernel_size=3,
               padding="valid",
               activation="relu",
               kernel_regularizer='l2'
               )
       )


model.add(LSTM(
         input_shape=(sequence_length, nb_features),
         units=100,
         return_sequences=True))


model.add(Dropout(0.2))
model.add(LSTM(
          units=100,
          return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(
          units=100,
          return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(
          units=100,
          return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=nb_out))
model.add(Activation("linear"))
model.compile(loss='mean_squared_error', optimizer='rmsprop',metrics=[rmse,r2_keras])
print(model.summary())

history = model.fit(seq_array, label_array, epochs=100, batch_size=512, validation_split=0.05, verbose=2,
          callbacks = [tensorflow.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=0, mode='min'),
                       tensorflow.keras.callbacks.ModelCheckpoint(model_path,monitor='val_loss', save_best_only=True, mode='min', verbose=0)]
    )

# model = Sequential()
# model.add(LSTM(
#          input_shape=(sequence_length, nb_features),
#          units=100,
#          return_sequences=True))
# model.add(Dropout(0.2))
# model.add(LSTM(
#           units=100,
#           return_sequences=False))
# model.add(Dropout(0.2))
# model.add(Dense(units=nb_out))
# model.add(Activation("linear"))
# model.compile(loss='mean_squared_error', optimizer='rmsprop',metrics=['mae',r2_keras])
#
# print(model.summary())
#
#
#
# # fit the network
# history = model.fit(seq_array, label_array, epochs=100, batch_size=200, validation_split=0.05, verbose=2,
#           callbacks = [keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=0, mode='min'),
#                        keras.callbacks.ModelCheckpoint(model_path,monitor='val_loss', save_best_only=True, mode='min', verbose=0)]
#           )

# list all data in history
print(history.history.keys())


# training metrics
scores = model.evaluate(seq_array, label_array, verbose=1, batch_size=200)
print('\nMAE: {}'.format(scores[1]))
print('\nR^2: {}'.format(scores[2]))

y_pred = model.predict(seq_array,verbose=1, batch_size=200)
y_true = label_array

test_set = pd.DataFrame(y_pred)
test_set.to_csv('/content/drive/MyDrive/PFC/FDIA-PdM/Output/submit_train_CNN-LSTM.csv', index = None)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 100, 25)          100
#  ormalization)
#
#  conv1d (Conv1D)             (None, 98, 64)            4864
#
#  lstm (LSTM)                 (None, 98, 100)           66000
#
#  dropout (Dropout)           (None, 98, 100)           0
#
#  lstm_1 (LSTM)               (None, 98, 100)           80400
#
#  dropout_1 (Dropout)         (None, 98, 100)           0
#
#  lstm_2 (LSTM)               (None, 98, 100)           80400
#
#  dropout_2 (Dropout)         (None, 98, 100)           0
#
#  lstm_3 (LSTM)               (None, 100)               80400
#
#  dropout_3 (Dropout)         (None, 100)               0
#
#  dense (Dense)               (None, 1)                 101
#
#  activation (Activation)     (None, 1)                 0
#
# =================================================================
# Total params: 312,265
# Trainable params: 312,215
# Non-trainable params: 50
# _________________________________________________________________
# None
# Epoch 1/100
# 52/52 - 19s - loss: 4545.4707 - rmse: 50.7518 - r2_keras: -1.1209e+00 - val_loss: 7930.4468 - val_rmse: 67.3852 - val_r2_keras: -1.2030e+00 - 19s/epoch - 362ms/step
# Epoch 2/100
# 52/52 - 3s - loss: 3935.9746 - rmse: 46.1657 - r2_keras: -8.3436e-01 - val_loss: 7287.2651 - val_rmse: 64.0156 - val_r2_keras: -1.0167e+00 - 3s/epoch - 57ms/step
# Epoch 3/100
# 52/52 - 3s - loss: 3527.8979 - rmse: 43.2500 - r2_keras: -6.4596e-01 - val_loss: 6704.3516 - val_rmse: 61.1031 - val_r2_keras: -8.4927e-01 - 3s/epoch - 57ms/step
# Epoch 4/100
# 52/52 - 3s - loss: 3176.5305 - rmse: 40.8424 - r2_keras: -4.8125e-01 - val_loss: 6177.0171 - val_rmse: 58.6200 - val_r2_keras: -6.9917e-01 - 3s/epoch - 56ms/step
# Epoch 5/100
# 52/52 - 3s - loss: 2878.5708 - rmse: 38.9665 - r2_keras: -3.4107e-01 - val_loss: 5704.7002 - val_rmse: 56.5531 - val_r2_keras: -5.6626e-01 - 3s/epoch - 57ms/step
# Epoch 6/100
# 52/52 - 3s - loss: 2633.3057 - rmse: 37.5249 - r2_keras: -2.2747e-01 - val_loss: 5286.1973 - val_rmse: 54.8671 - val_r2_keras: -4.5019e-01 - 3s/epoch - 59ms/step
# Epoch 7/100
# 52/52 - 3s - loss: 2441.0466 - rmse: 36.6060 - r2_keras: -1.3722e-01 - val_loss: 4922.9648 - val_rmse: 53.5410 - val_r2_keras: -3.5128e-01 - 3s/epoch - 57ms/step
# Epoch 8/100
# 52/52 - 3s - loss: 2302.5498 - rmse: 36.1262 - r2_keras: -7.2419e-02 - val_loss: 4619.0020 - val_rmse: 52.5513 - val_r2_keras: -2.7049e-01 - 3s/epoch - 57ms/step
# Epoch 9/100
# 52/52 - 3s - loss: 2213.1558 - rmse: 36.0649 - r2_keras: -3.1462e-02 - val_loss: 4408.0933 - val_rmse: 51.9473 - val_r2_keras: -2.1605e-01 - 3s/epoch - 57ms/step
# Epoch 10/100
# 52/52 - 3s - loss: 2172.3906 - rmse: 36.3299 - r2_keras: -1.3022e-02 - val_loss: 4215.8813 - val_rmse: 51.4904 - val_r2_keras: -1.6825e-01 - 3s/epoch - 57ms/step
# Epoch 11/100
# 52/52 - 3s - loss: 2158.7256 - rmse: 36.5830 - r2_keras: -7.2162e-03 - val_loss: 4173.8921 - val_rmse: 51.4078 - val_r2_keras: -1.5815e-01 - 3s/epoch - 57ms/step
# Epoch 12/100
# 52/52 - 3s - loss: 2157.6130 - rmse: 36.6182 - r2_keras: -6.2826e-03 - val_loss: 4156.4556 - val_rmse: 51.3750 - val_r2_keras: -1.5400e-01 - 3s/epoch - 57ms/step
# Epoch 13/100
# 52/52 - 3s - loss: 2158.5291 - rmse: 36.5796 - r2_keras: -6.9628e-03 - val_loss: 4178.4365 - val_rmse: 51.4159 - val_r2_keras: -1.5923e-01 - 3s/epoch - 56ms/step
# Epoch 14/100
# 52/52 - 3s - loss: 2090.6191 - rmse: 35.5285 - r2_keras: 0.0253 - val_loss: 4010.3718 - val_rmse: 50.0390 - val_r2_keras: -8.8497e-02 - 3s/epoch - 57ms/step
# Epoch 15/100
# 52/52 - 3s - loss: 1685.5151 - rmse: 29.9837 - r2_keras: 0.2149 - val_loss: 3435.1040 - val_rmse: 45.2120 - val_r2_keras: 0.0465 - 3s/epoch - 57ms/step
# Epoch 16/100
# 52/52 - 3s - loss: 1414.9277 - rmse: 26.3581 - r2_keras: 0.3425 - val_loss: 2832.4248 - val_rmse: 37.1184 - val_r2_keras: 0.2512 - 3s/epoch - 57ms/step
# Epoch 17/100
# 52/52 - 3s - loss: 1274.5028 - rmse: 24.5463 - r2_keras: 0.4077 - val_loss: 2600.7756 - val_rmse: 35.5391 - val_r2_keras: 0.3087 - 3s/epoch - 57ms/step
# Epoch 18/100
# 52/52 - 3s - loss: 1174.4019 - rmse: 23.3634 - r2_keras: 0.4536 - val_loss: 2382.7202 - val_rmse: 34.0803 - val_r2_keras: 0.3671 - 3s/epoch - 56ms/step
# Epoch 19/100
# 52/52 - 3s - loss: 1092.0801 - rmse: 22.4831 - r2_keras: 0.4915 - val_loss: 2120.0635 - val_rmse: 31.1022 - val_r2_keras: 0.4416 - 3s/epoch - 57ms/step
# Epoch 20/100
# 52/52 - 3s - loss: 1038.2240 - rmse: 21.7437 - r2_keras: 0.5182 - val_loss: 2073.8740 - val_rmse: 31.8148 - val_r2_keras: 0.4466 - 3s/epoch - 56ms/step
# Epoch 21/100
# 52/52 - 3s - loss: 989.8167 - rmse: 21.6341 - r2_keras: 0.5388 - val_loss: 1972.3508 - val_rmse: 30.5949 - val_r2_keras: 0.4802 - 3s/epoch - 57ms/step
# Epoch 22/100
# 52/52 - 3s - loss: 902.0545 - rmse: 20.3344 - r2_keras: 0.5805 - val_loss: 1919.6796 - val_rmse: 29.2104 - val_r2_keras: 0.5025 - 3s/epoch - 56ms/step
# Epoch 23/100
# 52/52 - 3s - loss: 874.3292 - rmse: 20.0996 - r2_keras: 0.5943 - val_loss: 1648.7137 - val_rmse: 25.9562 - val_r2_keras: 0.5702 - 3s/epoch - 57ms/step
# Epoch 24/100
# 52/52 - 3s - loss: 815.8821 - rmse: 19.2958 - r2_keras: 0.6200 - val_loss: 1554.6526 - val_rmse: 25.6555 - val_r2_keras: 0.5893 - 3s/epoch - 56ms/step
# Epoch 25/100
# 52/52 - 3s - loss: 792.8696 - rmse: 19.1366 - r2_keras: 0.6305 - val_loss: 1333.6287 - val_rmse: 23.5423 - val_r2_keras: 0.6546 - 3s/epoch - 57ms/step
# Epoch 26/100
# 52/52 - 3s - loss: 743.4831 - rmse: 18.5417 - r2_keras: 0.6537 - val_loss: 1373.3788 - val_rmse: 26.1430 - val_r2_keras: 0.6316 - 3s/epoch - 55ms/step
# Epoch 27/100
# 52/52 - 3s - loss: 701.1467 - rmse: 17.9611 - r2_keras: 0.6734 - val_loss: 1228.4600 - val_rmse: 23.1703 - val_r2_keras: 0.6741 - 3s/epoch - 57ms/step
# Epoch 28/100
# 52/52 - 3s - loss: 690.8806 - rmse: 17.6845 - r2_keras: 0.6790 - val_loss: 1644.4753 - val_rmse: 27.9133 - val_r2_keras: 0.5769 - 3s/epoch - 56ms/step
# Epoch 29/100
# 52/52 - 3s - loss: 680.4756 - rmse: 17.6222 - r2_keras: 0.6854 - val_loss: 1154.1475 - val_rmse: 21.4529 - val_r2_keras: 0.7081 - 3s/epoch - 57ms/step
# Epoch 30/100
# 52/52 - 3s - loss: 621.0110 - rmse: 16.7888 - r2_keras: 0.7100 - val_loss: 1299.4229 - val_rmse: 22.0374 - val_r2_keras: 0.6662 - 3s/epoch - 56ms/step
# Epoch 31/100
# 52/52 - 3s - loss: 632.1924 - rmse: 17.0071 - r2_keras: 0.7055 - val_loss: 1032.1611 - val_rmse: 20.2960 - val_r2_keras: 0.7375 - 3s/epoch - 57ms/step
# Epoch 32/100
# 52/52 - 3s - loss: 618.4412 - rmse: 16.7448 - r2_keras: 0.7137 - val_loss: 1028.0857 - val_rmse: 20.8199 - val_r2_keras: 0.7376 - 3s/epoch - 57ms/step
# Epoch 33/100
# 52/52 - 3s - loss: 554.6864 - rmse: 15.8965 - r2_keras: 0.7418 - val_loss: 1269.8596 - val_rmse: 23.7439 - val_r2_keras: 0.6885 - 3s/epoch - 56ms/step
# Epoch 34/100
# 52/52 - 3s - loss: 541.8487 - rmse: 15.6545 - r2_keras: 0.7475 - val_loss: 893.8567 - val_rmse: 19.1141 - val_r2_keras: 0.7806 - 3s/epoch - 57ms/step
# Epoch 35/100
# 52/52 - 3s - loss: 504.5646 - rmse: 15.0966 - r2_keras: 0.7667 - val_loss: 904.4468 - val_rmse: 19.6999 - val_r2_keras: 0.7630 - 3s/epoch - 56ms/step
# Epoch 36/100
# 52/52 - 3s - loss: 504.0203 - rmse: 15.1161 - r2_keras: 0.7649 - val_loss: 995.4344 - val_rmse: 19.4560 - val_r2_keras: 0.7374 - 3s/epoch - 55ms/step
# Epoch 37/100
# 52/52 - 3s - loss: 522.5915 - rmse: 15.2599 - r2_keras: 0.7574 - val_loss: 796.1621 - val_rmse: 18.3400 - val_r2_keras: 0.7965 - 3s/epoch - 57ms/step
# Epoch 38/100
# 52/52 - 3s - loss: 451.9581 - rmse: 14.2232 - r2_keras: 0.7889 - val_loss: 993.0073 - val_rmse: 20.2784 - val_r2_keras: 0.7528 - 3s/epoch - 56ms/step
# Epoch 39/100
# 52/52 - 3s - loss: 457.6015 - rmse: 14.3204 - r2_keras: 0.7877 - val_loss: 773.1673 - val_rmse: 18.4307 - val_r2_keras: 0.7934 - 3s/epoch - 57ms/step
# Epoch 40/100
# 52/52 - 3s - loss: 430.8655 - rmse: 13.8958 - r2_keras: 0.7985 - val_loss: 950.3716 - val_rmse: 20.1804 - val_r2_keras: 0.7601 - 3s/epoch - 55ms/step
# Epoch 41/100
# 52/52 - 3s - loss: 421.0072 - rmse: 13.7004 - r2_keras: 0.8032 - val_loss: 946.1239 - val_rmse: 20.3429 - val_r2_keras: 0.7690 - 3s/epoch - 56ms/step
# Epoch 42/100
# 52/52 - 3s - loss: 406.0667 - rmse: 13.4305 - r2_keras: 0.8116 - val_loss: 726.3567 - val_rmse: 15.7726 - val_r2_keras: 0.8200 - 3s/epoch - 62ms/step
# Epoch 43/100
# 52/52 - 3s - loss: 378.0504 - rmse: 12.8390 - r2_keras: 0.8226 - val_loss: 957.1285 - val_rmse: 18.6047 - val_r2_keras: 0.7498 - 3s/epoch - 56ms/step
# Epoch 44/100
# 52/52 - 3s - loss: 377.7990 - rmse: 12.9223 - r2_keras: 0.8248 - val_loss: 599.1749 - val_rmse: 14.3063 - val_r2_keras: 0.8515 - 3s/epoch - 57ms/step
# Epoch 45/100
# 52/52 - 3s - loss: 341.7142 - rmse: 12.2609 - r2_keras: 0.8413 - val_loss: 905.2924 - val_rmse: 17.9093 - val_r2_keras: 0.7766 - 3s/epoch - 56ms/step
# Epoch 46/100
# 52/52 - 3s - loss: 345.0930 - rmse: 12.4167 - r2_keras: 0.8400 - val_loss: 952.7157 - val_rmse: 19.1551 - val_r2_keras: 0.7522 - 3s/epoch - 55ms/step
# Epoch 47/100
# 52/52 - 3s - loss: 330.0343 - rmse: 12.0834 - r2_keras: 0.8461 - val_loss: 736.7949 - val_rmse: 16.3289 - val_r2_keras: 0.8076 - 3s/epoch - 56ms/step
# Epoch 48/100
# 52/52 - 3s - loss: 309.1761 - rmse: 11.6572 - r2_keras: 0.8558 - val_loss: 735.6550 - val_rmse: 18.0036 - val_r2_keras: 0.8028 - 3s/epoch - 56ms/step
# Epoch 49/100
# 52/52 - 3s - loss: 302.5519 - rmse: 11.5811 - r2_keras: 0.8594 - val_loss: 627.5649 - val_rmse: 15.4568 - val_r2_keras: 0.8397 - 3s/epoch - 56ms/step
# Epoch 50/100
# 52/52 - 3s - loss: 271.1649 - rmse: 10.8428 - r2_keras: 0.8741 - val_loss: 696.3174 - val_rmse: 14.1935 - val_r2_keras: 0.8382 - 3s/epoch - 56ms/step
# Epoch 51/100
# 52/52 - 3s - loss: 283.3099 - rmse: 11.1902 - r2_keras: 0.8691 - val_loss: 589.1057 - val_rmse: 14.8587 - val_r2_keras: 0.8530 - 3s/epoch - 63ms/step
# Epoch 52/100
# 52/52 - 3s - loss: 249.1766 - rmse: 10.3524 - r2_keras: 0.8840 - val_loss: 634.7570 - val_rmse: 15.2845 - val_r2_keras: 0.8446 - 3s/epoch - 56ms/step
# Epoch 53/100
# 52/52 - 3s - loss: 236.3698 - rmse: 10.2502 - r2_keras: 0.8911 - val_loss: 686.3177 - val_rmse: 15.0092 - val_r2_keras: 0.8333 - 3s/epoch - 56ms/step
# Epoch 54/100
# 52/52 - 3s - loss: 222.7406 - rmse: 9.9774 - r2_keras: 0.8969 - val_loss: 880.7762 - val_rmse: 18.6519 - val_r2_keras: 0.7552 - 3s/epoch - 56ms/step
# Epoch 55/100
# 52/52 - 3s - loss: 209.7740 - rmse: 9.6680 - r2_keras: 0.9034 - val_loss: 871.1899 - val_rmse: 18.4901 - val_r2_keras: 0.7623 - 3s/epoch - 56ms/step
# Epoch 56/100
# 52/52 - 3s - loss: 201.5267 - rmse: 9.4989 - r2_keras: 0.9059 - val_loss: 1021.6221 - val_rmse: 20.2048 - val_r2_keras: 0.7448 - 3s/epoch - 56ms/step
# Epoch 57/100
# 52/52 - 3s - loss: 173.3061 - rmse: 8.7128 - r2_keras: 0.9184 - val_loss: 1251.3627 - val_rmse: 22.7331 - val_r2_keras: 0.6442 - 3s/epoch - 56ms/step
# Epoch 58/100
# 52/52 - 3s - loss: 170.9436 - rmse: 8.8419 - r2_keras: 0.9204 - val_loss: 881.2352 - val_rmse: 17.4382 - val_r2_keras: 0.7838 - 3s/epoch - 55ms/step
# Epoch 59/100
# 52/52 - 3s - loss: 152.2333 - rmse: 8.2787 - r2_keras: 0.9293 - val_loss: 856.3996 - val_rmse: 18.0502 - val_r2_keras: 0.7906 - 3s/epoch - 56ms/step
# Epoch 60/100
# 52/52 - 3s - loss: 154.8175 - rmse: 8.4054 - r2_keras: 0.9279 - val_loss: 982.0060 - val_rmse: 18.0120 - val_r2_keras: 0.7550 - 3s/epoch - 55ms/step
# Epoch 61/100
# 52/52 - 3s - loss: 133.7693 - rmse: 7.6780 - r2_keras: 0.9377 - val_loss: 1032.2638 - val_rmse: 19.0098 - val_r2_keras: 0.7348 - 3s/epoch - 56ms/step
# dict_keys(['loss', 'rmse', 'r2_keras', 'val_loss', 'val_rmse', 'val_r2_keras'])
# 139/139 [==============================] - 2s 15ms/step - loss: 165.6804 - rmse: 7.7912 - r2_keras: 0.9233
#
# MAE: 7.79122257232666
#
# R^2: 0.9233197569847107
# 139/139 [==============================] - 3s 14ms/step

# %% [markdown]
# #6. EVALUATE ON TEST DATA

# %%
# We pick the last sequence for each id in the test data
seq_array_test_last = [test_df[test_df['id']==id][sequence_cols].values[-sequence_length:] 
                       for id in test_df['id'].unique() if len(test_df[test_df['id']==id]) >= sequence_length]

seq_array_test_last = np.asarray(seq_array_test_last).astype(np.float32)
print("seq_array_test_last")
#print(seq_array_test_last)
print(seq_array_test_last.shape)

# Similarly, we pick the labels
#print("y_mask")
y_mask = [len(test_df[test_df['id']==id]) >= sequence_length for id in test_df['id'].unique()]
label_array_test_last = test_df.groupby('id')['RUL'].nth(-1)[y_mask].values
label_array_test_last = label_array_test_last.reshape(label_array_test_last.shape[0],1).astype(np.float32)
print(label_array_test_last.shape)
print("label_array_test_last")
print(label_array_test_last)

# if best iteration's model was saved then load and use it
if os.path.isfile(model_path):
    model.load_weights(model_path)
    #estimator = load_model(model_path,custom_objects={'r2_keras': r2_keras})

    # test metrics
    scores_test = model.evaluate(seq_array_test_last, label_array_test_last, verbose=2)
    print('\nMAE: {}'.format(scores_test[1]))
    print('\nR^2: {}'.format(scores_test[2]))

    y_pred_test = model.predict(seq_array_test_last)
    y_true_test = label_array_test_last
    print("Prediction")
    print(y_pred_test);
    print("Truth")
    print(y_true_test);

    # Plot in blue color the predicted data and in green color the
    # actual data to verify visually the accuracy of the model.
    fig_verify = plt.figure(figsize=(100, 50))
    plt.plot(y_pred_test, color="blue")
    plt.plot(y_true_test, color="green")
    plt.title('prediction')
    plt.ylabel('RUL in cycles')
    plt.xlabel('Engine ID')
    plt.legend(['predicted', 'actual data'], loc='upper left')
    plt.show()
    fig_verify.savefig("/content/drive/MyDrive/PFC/FDIA-PdM/Output/model_regression_verify_CNN.png")
# Out:
# seq_array_test_last
# (168, 100, 25)
# (168, 1)
# label_array_test_last
# [[ 18.]
#  [106.]
#  [ 15.]
#  [  6.]
#  [ 90.]
#  [ 11.]
#  [  6.]
#  [ 30.]
#  [ 11.]
#  [ 37.]
#  [ 68.]
#  [ 22.]
#  [ 54.]
#  [ 97.]
#  [ 10.]
#  [ 77.]
#  [ 88.]
#  [ 83.]
#  [ 78.]
#  [ 75.]
#  [ 11.]
#  [ 53.]
#  [100.]
#  [ 55.]
#  [ 48.]
#  [ 37.]
#  [ 44.]
#  [ 27.]
#  [ 18.]
#  [  6.]
#  [ 15.]
#  [112.]
#  [ 13.]
#  [ 13.]
#  [ 53.]
#  [ 52.]
#  [103.]
#  [ 26.]
#  [ 73.]
#  [ 39.]
#  [ 39.]
#  [ 14.]
#  [ 11.]
#  [ 86.]
#  [ 56.]
#  [115.]
#  [ 17.]
#  [104.]
#  [ 78.]
#  [ 86.]
#  [ 98.]
#  [ 36.]
#  [ 52.]
#  [ 91.]
#  [ 15.]
#  [ 17.]
#  [ 47.]
#  [ 21.]
#  [ 79.]
#  [  8.]
#  [  9.]
#  [ 73.]
#  [ 97.]
#  [ 49.]
#  [ 31.]
#  [ 97.]
#  [  9.]
#  [ 14.]
#  [  8.]
#  [  8.]
#  [106.]
#  [ 61.]
#  [168.]
#  [ 35.]
#  [ 80.]
#  [  9.]
#  [ 50.]
#  [ 78.]
#  [ 91.]
#  [  7.]
#  [106.]
#  [ 15.]
#  [  7.]
#  [ 82.]
#  [108.]
#  [ 79.]
#  [121.]
#  [ 39.]
#  [ 38.]
#  [  9.]
#  [167.]
#  [ 88.]
#  [  7.]
#  [ 51.]
#  [ 55.]
#  [ 47.]
#  [ 81.]
#  [ 43.]
#  [ 98.]
#  [ 10.]
#  [ 11.]
#  [ 34.]
#  [115.]
#  [ 99.]
#  [171.]
#  [ 15.]
#  [  9.]
#  [ 42.]
#  [ 13.]
#  [ 41.]
#  [ 88.]
#  [ 14.]
#  [ 82.]
#  [ 36.]
#  [107.]
#  [ 14.]
#  [ 23.]
#  [  6.]
#  [ 35.]
#  [ 97.]
#  [ 68.]
#  [ 14.]
#  [ 67.]
#  [ 19.]
#  [ 10.]
#  [ 43.]
#  [ 12.]
#  [ 13.]
#  [ 37.]
#  [ 80.]
#  [ 93.]
#  [ 32.]
#  [103.]
#  [ 68.]
#  [192.]
#  [ 48.]
#  [ 85.]
#  [  8.]
#  [ 23.]
#  [  8.]
#  [  6.]
#  [ 57.]
#  [ 83.]
#  [ 81.]
#  [ 73.]
#  [ 75.]
#  [ 11.]
#  [108.]
#  [ 14.]
#  [ 61.]
#  [ 85.]
#  [  8.]
#  [101.]
#  [ 89.]
#  [190.]
#  [ 12.]
#  [ 62.]
#  [101.]
#  [ 17.]
#  [ 16.]
#  [ 56.]
#  [ 23.]
#  [ 12.]
#  [ 43.]
#  [ 48.]
#  [122.]
#  [ 56.]
#  [ 51.]]
# 6/6 - 0s - loss: 224.7890 - rmse: 10.1265 - r2_keras: 0.8493 - 77ms/epoch - 13ms/step
#
# MAE: 10.126527786254883
#
# R^2: 0.8492729663848877
# Prediction
# [[ 12.281852 ]
#  [ 94.54943  ]
#  [ 17.761396 ]
#  [  8.7221575]
#  [ 77.97678  ]
#  [  6.968364 ]
#  [  7.999447 ]
#  [ 32.16609  ]
#  [ 15.646718 ]
#  [ 35.91332  ]
#  [ 87.164055 ]
#  [ 31.674623 ]
#  [ 76.84031  ]
#  [119.51708  ]
#  [ 11.453545 ]
#  [111.653175 ]
#  [ 84.731705 ]
#  [ 84.44839  ]
#  [ 99.10201  ]
#  [ 66.42582  ]
#  [ 10.994312 ]
#  [ 80.51392  ]
#  [103.85977  ]
#  [ 54.035454 ]
#  [ 53.680244 ]
#  [ 47.268456 ]
#  [ 28.254969 ]
#  [ 28.431263 ]
#  [ 17.705442 ]
#  [  8.811529 ]
#  [ 17.453281 ]
#  [150.45615  ]
#  [ 17.72906  ]
#  [ 10.782134 ]
#  [ 42.597107 ]
#  [ 42.692123 ]
#  [ 80.893814 ]
#  [ 29.383938 ]
#  [ 78.53074  ]
#  [ 29.590273 ]
#  [ 40.531425 ]
#  [ 15.949666 ]
#  [ 19.188322 ]
#  [120.02095  ]
#  [ 60.98961  ]
#  [109.33872  ]
#  [ 18.332432 ]
#  [ 92.118774 ]
#  [ 87.70266  ]
#  [ 84.97413  ]
#  [110.56246  ]
#  [ 27.273314 ]
#  [ 63.630276 ]
#  [157.30074  ]
#  [ 12.677516 ]
#  [ 20.650232 ]
#  [ 34.993553 ]
#  [ 25.651028 ]
#  [ 84.78249  ]
#  [  7.6510115]
#  [ 20.926807 ]
#  [ 98.93596  ]
#  [117.81596  ]
#  [ 40.580784 ]
#  [ 31.471779 ]
#  [128.36734  ]
#  [  5.67766  ]
#  [ 21.384691 ]
#  [ 18.902533 ]
#  [ 10.234706 ]
#  [111.84699  ]
#  [ 71.3537   ]
#  [120.81723  ]
#  [ 41.305527 ]
#  [ 89.41338  ]
#  [ 18.051373 ]
#  [ 45.18424  ]
#  [ 76.542564 ]
#  [ 76.80807  ]
#  [ 11.910862 ]
#  [ 95.52497  ]
#  [ 25.779367 ]
#  [ 14.775243 ]
#  [ 83.23946  ]
#  [ 96.58242  ]
#  [ 92.113556 ]
#  [121.068886 ]
#  [ 40.391457 ]
#  [ 52.440052 ]
#  [ 11.618662 ]
#  [134.77965  ]
#  [ 92.27549  ]
#  [ 10.578183 ]
#  [ 73.018936 ]
#  [ 61.2067   ]
#  [ 63.640392 ]
#  [ 89.10786  ]
#  [ 49.578777 ]
#  [105.89676  ]
#  [ 12.040661 ]
#  [ 14.95145  ]
#  [ 28.866802 ]
#  [ 77.13088  ]
#  [155.28558  ]
#  [144.6942   ]
#  [ 21.384987 ]
#  [ 16.399107 ]
#  [ 32.929512 ]
#  [ 17.87109  ]
#  [ 44.474926 ]
#  [ 78.82018  ]
#  [  7.85915  ]
#  [ 89.71575  ]
#  [ 40.718132 ]
#  [103.91832  ]
#  [ 13.603932 ]
#  [ 21.211288 ]
#  [  7.7696085]
#  [ 38.712273 ]
#  [101.44169  ]
#  [ 49.083942 ]
#  [ 23.36416  ]
#  [ 73.11173  ]
#  [ 22.947826 ]
#  [  8.186916 ]
#  [ 55.867672 ]
#  [ 21.221565 ]
#  [ 17.44691  ]
#  [ 39.51761  ]
#  [ 80.12211  ]
#  [108.88769  ]
#  [ 36.168423 ]
#  [125.09906  ]
#  [ 78.28716  ]
#  [157.43106  ]
#  [ 50.25626  ]
#  [ 98.0054   ]
#  [  7.851778 ]
#  [ 29.067009 ]
#  [ 14.242417 ]
#  [ 17.003895 ]
#  [ 55.02666  ]
#  [114.89836  ]
#  [110.42131  ]
#  [ 77.49642  ]
#  [ 74.32456  ]
#  [ 16.88726  ]
#  [108.178474 ]
#  [ 11.304443 ]
#  [ 84.76294  ]
#  [125.73593  ]
#  [  4.897788 ]
#  [119.50058  ]
#  [ 83.478485 ]
#  [157.32953  ]
#  [ 13.428524 ]
#  [ 47.182003 ]
#  [ 99.32981  ]
#  [ 21.884356 ]
#  [ 14.831208 ]
#  [ 70.07094  ]
#  [ 25.596348 ]
#  [ 17.93644  ]
#  [ 35.855343 ]
#  [ 37.90568  ]
#  [115.33     ]
#  [ 65.49509  ]
#  [ 74.67133  ]]
# Truth
# [[ 18.]
#  [106.]
#  [ 15.]
#  [  6.]
#  [ 90.]
#  [ 11.]
#  [  6.]
#  [ 30.]
#  [ 11.]
#  [ 37.]
#  [ 68.]
#  [ 22.]
#  [ 54.]
#  [ 97.]
#  [ 10.]
#  [ 77.]
#  [ 88.]
#  [ 83.]
#  [ 78.]
#  [ 75.]
#  [ 11.]
#  [ 53.]
#  [100.]
#  [ 55.]
#  [ 48.]
#  [ 37.]
#  [ 44.]
#  [ 27.]
#  [ 18.]
#  [  6.]
#  [ 15.]
#  [112.]
#  [ 13.]
#  [ 13.]
#  [ 53.]
#  [ 52.]
#  [103.]
#  [ 26.]
#  [ 73.]
#  [ 39.]
#  [ 39.]
#  [ 14.]
#  [ 11.]
#  [ 86.]
#  [ 56.]
#  [115.]
#  [ 17.]
#  [104.]
#  [ 78.]
#  [ 86.]
#  [ 98.]
#  [ 36.]
#  [ 52.]
#  [ 91.]
#  [ 15.]
#  [ 17.]
#  [ 47.]
#  [ 21.]
#  [ 79.]
#  [  8.]
#  [  9.]
#  [ 73.]
#  [ 97.]
#  [ 49.]
#  [ 31.]
#  [ 97.]
#  [  9.]
#  [ 14.]
#  [  8.]
#  [  8.]
#  [106.]
#  [ 61.]
#  [168.]
#  [ 35.]
#  [ 80.]
#  [  9.]
#  [ 50.]
#  [ 78.]
#  [ 91.]
#  [  7.]
#  [106.]
#  [ 15.]
#  [  7.]
#  [ 82.]
#  [108.]
#  [ 79.]
#  [121.]
#  [ 39.]
#  [ 38.]
#  [  9.]
#  [167.]
#  [ 88.]
#  [  7.]
#  [ 51.]
#  [ 55.]
#  [ 47.]
#  [ 81.]
#  [ 43.]
#  [ 98.]
#  [ 10.]
#  [ 11.]
#  [ 34.]
#  [115.]
#  [ 99.]
#  [171.]
#  [ 15.]
#  [  9.]
#  [ 42.]
#  [ 13.]
#  [ 41.]
#  [ 88.]
#  [ 14.]
#  [ 82.]
#  [ 36.]
#  [107.]
#  [ 14.]
#  [ 23.]
#  [  6.]
#  [ 35.]
#  [ 97.]
#  [ 68.]
#  [ 14.]
#  [ 67.]
#  [ 19.]
#  [ 10.]
#  [ 43.]
#  [ 12.]
#  [ 13.]
#  [ 37.]
#  [ 80.]
#  [ 93.]
#  [ 32.]
#  [103.]
#  [ 68.]
#  [192.]
#  [ 48.]
#  [ 85.]
#  [  8.]
#  [ 23.]
#  [  8.]
#  [  6.]
#  [ 57.]
#  [ 83.]
#  [ 81.]
#  [ 73.]
#  [ 75.]
#  [ 11.]
#  [108.]
#  [ 14.]
#  [ 61.]
#  [ 85.]
#  [  8.]
#  [101.]
#  [ 89.]
#  [190.]
#  [ 12.]
#  [ 62.]
#  [101.]
#  [ 17.]
#  [ 16.]
#  [ 56.]
#  [ 23.]
#  [ 12.]
#  [ 43.]
#  [ 48.]
#  [122.]
#  [ 56.]
#  [ 51.]]
